# %%
import pandas as pd
import numpy as np
import os
import dotenv
import json
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# # You need to sign up for the Spotify API and get your own client id and client secret.
# ## I put mine in a .env like we did in Kropko's class.

# %%
dotenv.load_dotenv()
Client_ID=os.getenv('Client_ID')
Client_Secret=os.getenv('Client_Secret')

# %% [markdown]
# # Here I am just doing a track search on a band and then printing out the top 20 results

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

results = sp.search(q='Peach Pit', limit=20)
#results2 = sp.search(q='Drake', limit=20)
#results3 = sp.search(q='top songs')
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Peach Pit
# 1 Alrighty Aphrodite
# 2 Figure 8
# 3 Shampoo Bottles
# 4 Tommy's Party
# 5 Vickie
# 6 Drop the Guillotine
# 7 Up Granville
# 8 Peach Pit
# 9 Peach Pit
# 10 Look Out!
# 11 Peach Pit
# 12 Seventeen
# 13 Peach Pit
# 14 Techno Show
# 15 Peach Pit
# 16 Black Licorice
# 17 Peach Pit
# 18 Being so Normal
# 19 Peach Pit

# %% [markdown]
# ## Search for playlists

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

results = sp.search(q='jazz', limit=20, type='playlist')

# %% [markdown]
# ## Getting items in a playlist

# %%
pd.DataFrame(results['playlists']['items'])

results['playlists']['items'][0]['uri']#['spotify']
# Out:
# 'spotify:playlist:37i9dQZF1DWWfxnl2EyBbd'

# %%
holder = sp.playlist_items(results['playlists']['items'][0]['uri'])

# %%
holder.keys()
holder['items'][0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5isSr1JUeHt5cgh8oWz1Ja'},
#     'href': 'https://api.spotify.com/v1/artists/5isSr1JUeHt5cgh8oWz1Ja',
#     'id': '5isSr1JUeHt5cgh8oWz1Ja',
#     'name': 'Bill Charlap Trio',
#     'type': 'artist',
#     'uri': 'spotify:artist:5isSr1JUeHt5cgh8oWz1Ja'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
# ...

# %%
pd.DataFrame(holder)
# Out:
#                                                  href  \
# 0   https://api.spotify.com/v1/playlists/37i9dQZF1...
# 1   https://api.spotify.com/v1/playlists/37i9dQZF1...
# 2   https://api.spotify.com/v1/playlists/37i9dQZF1...
# 3   https://api.spotify.com/v1/playlists/37i9dQZF1...
# 4   https://api.spotify.com/v1/playlists/37i9dQZF1...
# ..                                                ...
# 95  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 96  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 97  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 98  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 99  https://api.spotify.com/v1/playlists/37i9dQZF1...
#
#                                                 items  limit  next  offset  \
# 0   {'added_at': '2022-02-10T23:00:00Z', 'added_by...    100  None       0
# 1   {'added_at': '2022-02-10T23:00:00Z', 'added_by...    100  None       0
# 2   {'added_at': '2022-02-10T23:00:00Z', 'added_by...    100  None       0
# ...

# %%
dir(sp)
#sp.recommendation_genre_seeds
#sp.recommendations(seed_genres='acoustic')
#sp.recommendations?
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_append_device_id',
#  '_auth',
#  '_auth_headers',
#  '_auth_manager',
#  '_build_session',
#  '_delete',
#  '_get',
#  '_get_id',
#  '_get_uri',
#  '_internal_call',
#  '_is_uri',
#  '_post',
#  '_put',
#  '_search_multiple_markets',
#  '_session',
#  'add_to_queue',
#  'album',
#  'album_tracks',
#  'albums',
#  'artist',
#  'artist_albums',
#  'artist_related_artists',
#  'artist_top_tracks',
#  'artists',
#  'audio_analysis',
#  'audio_features',
#  'auth_manager',
#  'available_markets',
#  'backoff_factor',
#  'categories',
#  'category',
# ...

# %% [markdown]
# ## Gets a list of the genres

# %%
genre_dict = sp._get('https://api.spotify.com/v1/recommendations/available-genre-seeds')

# %%
genres = genre_dict['genres']
print(len(genres))
genres
# Out:
# 126
# ['acoustic',
#  'afrobeat',
#  'alt-rock',
#  'alternative',
#  'ambient',
#  'anime',
#  'black-metal',
#  'bluegrass',
#  'blues',
#  'bossanova',
#  'brazil',
#  'breakbeat',
#  'british',
#  'cantopop',
#  'chicago-house',
#  'children',
#  'chill',
#  'classical',
#  'club',
#  'comedy',
#  'country',
#  'dance',
#  'dancehall',
#  'death-metal',
#  'deep-house',
#  'detroit-techno',
#  'disco',
#  'disney',
#  'drum-and-bass',
#  'dub',
#  'dubstep',
#  'edm',
#  'electro',
#  'electronic',
#  'emo',
#  'folk',
#  'forro',
#  'french',
#  'funk',
#  'garage',
#  'german',
#  'gospel',
#  'goth',
#  'grindcore',
#  'groove',
#  'grunge',
#  'guitar',
#  'happy',
#  'hard-rock',
#  'hardcore',
#  'hardstyle',
#  'heavy-metal',
#  'hip-hop',
#  'holidays',
#  'honky-tonk',
#  'house',
#  'idm',
#  'indian',
#  'indie',
#  'indie-pop',
#  'industrial',
#  'iranian',
#  'j-dance',
#  'j-idol',
#  'j-pop',
#  'j-rock',
#  'jazz',
#  'k-pop',
#  'kids',
#  'latin',
#  'latino',
# ...

# %% [markdown]
# # This is how I put the search results into a dataframe

# %%
pd.json_normalize(results['tracks']['items'])
# Out:
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# ...

# %% [markdown]
# # Print column names

# %%
pd.json_normalize(results2['tracks']['items']).columns.unique()
# Out:
# Index(['artists', 'available_markets', 'disc_number', 'duration_ms',
#        'explicit', 'href', 'id', 'is_local', 'name', 'popularity',
#        'preview_url', 'track_number', 'type', 'uri', 'album.album_type',
#        'album.artists', 'album.available_markets',
#        'album.external_urls.spotify', 'album.href', 'album.id', 'album.images',
#        'album.name', 'album.release_date', 'album.release_date_precision',
#        'album.total_tracks', 'album.type', 'album.uri', 'external_ids.isrc',
#        'external_urls.spotify'],
#       dtype='object')

# %% [markdown]
# # This is how i found some links to the album cover art

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(lz_uri)

audios = []
for track in results['tracks'][:10]:
    audios.append(track['preview_url'])
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()

# %% [markdown]
# # This is where I searched for dancebility, energy, etc. for the top 50 weezer songs

# %%
artist_name = 'weezer'

results = sp.search(q=artist_name, limit=50)
tids = []
for i, t in enumerate(results['tracks']['items']):
    #print(' ', i, t['name'])
    tids.append(t['uri'])
    
features = sp.audio_features(tids)

pd.DataFrame.from_dict(features)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.634  0.5510    3    -7.136     1       0.0352      0.007370
# 1          0.654  0.8100    4    -6.260     0       0.0288      0.007190
# 2          0.457  0.6180    6    -6.682     1       0.0296      0.001140
# 3          0.556  0.9200    8    -4.606     1       0.0367      0.002710
# 4          0.693  0.8230    5    -3.761     1       0.0726      0.093200
# 5          0.534  0.7840    8    -3.590     1       0.0339      0.205000
# 6          0.578  0.8820    7    -6.354     1       0.0440      0.000121
# 7          0.605  0.7000    4    -6.470     1       0.0277      0.009980
# 8          0.295  0.9400   11    -5.247     1       0.0449      0.000210
# 9          0.599  0.6240    6    -6.622     1       0.0339      0.010900
# 10         0.531  0.8500    3    -5.162     1       0.0485      0.001060
# 11         0.403  0.5980    8    -5.735     1       0.0241      0.198000
# ...

# %% [markdown]
# # Junk that I did a while ago and I don't remember what it actually does

# %%
from spotipy.oauth2 import SpotifyOAuth

scope = 'playlist-read-private'
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope,client_id=Client_ID,client_secret=Client_Secret))

results = sp.current_user_playlists(limit=50)
for i, item in enumerate(results['items']):
    print("%d %s" % (i, item['name']))
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-6-4098c88d9059> in <module>
#       2
#       3 scope = 'playlist-read-private'
# ----> 4 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope,client_id=Client_ID,client_secret=Client_Secret))
#       5
#       6 results = sp.current_user_playlists(limit=50)
#
# ~/anaconda/lib/python3.6/site-packages/spotipy/oauth2.py in __init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     332         self.client_id = client_id
#     333         self.client_secret = client_secret
# --> 334         self.redirect_uri = redirect_uri
#     335         self.state = state
#     336         self.scope = self._normalize_scope(scope)
#
# ...

# %%
import argparse
import logging

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials


logger = logging.getLogger('examples.artist_recommendations')
logging.basicConfig(level='INFO')

client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


def get_args():
    parser = argparse.ArgumentParser(description='Recommendations for the '
                                     'given artist')
    parser.add_argument('-a', '--artist', required=True, help='Name of Artist')
    return parser.parse_args()


def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None


def show_recommendations_for_artist(artist):
    results = sp.recommendations(seed_artists=[artist['id']])
    for track in results['tracks']:
        logger.info('Recommendation: %s - %s', track['name'],
                    track['artists'][0]['name'])


def main():
    args = get_args()
    artist = get_artist(args.artist)
    if artist:
        show_recommendations_for_artist(artist)
    else:
        logger.error("Can't find that artist", args.artist)


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-7-6698652f1bb5> in <module>
#       9 logging.basicConfig(level='INFO')
#      10
# ---> 11 client_credentials_manager = SpotifyClientCredentials()
#      12 sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
#      13
#
# ~/anaconda/lib/python3.6/site-packages/spotipy/oauth2.py in __init__(self, client_id, client_secret, proxies, requests_session, requests_timeout, cache_handler)
#     199         super(SpotifyClientCredentials, self).__init__(requests_session)
#     200
# --> 201         self.client_id = client_id
#     202         self.client_secret = client_secret
#     203         self.proxies = proxies
#
# ~/anaconda/lib/python3.6/site-packages/spotipy/oauth2.py in client_id(self, val)
#      92     @client_id.setter
#      93     def client_id(self, val):
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

SpotifyClientCredentials.client_id = os.getenv('Client_ID')
SpotifyClientCredentials.client_secret = os.getenv('Client_Secret')

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Young Heart
# Beautiful Lies
# Beautiful Lies
# Beautiful Lies (Deluxe)
# Beautiful Lies (Deluxe)
# Fire Within
# Fire Within
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy
# Birdy
# Birdy
# Birdy
# Birdy (Deluxe Version)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(lz_uri)

audios = []
for track in results['tracks'][:10]:
    audios.append(track['preview_url'])
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=c32a5873a74344fbb4a8e4a0731f6a13
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/8455599677a13017978dcd3f4b210937f0a16bcb?cid=c32a5873a74344fbb4a8e4a0731f6a13
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/ce11b19a4d2de9976d7626df0717d0073863909c?cid=c32a5873a74344fbb4a8e4a0731f6a13
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/9b76619fd9d563a48d38cc90ca00c3008327b52e?cid=c32a5873a74344fbb4a8e4a0731f6a13
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Kashmir - Remaster
# ...

# %%
audios[0]
# Out:
# 'https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=c32a5873a74344fbb4a8e4a0731f6a13'

# %%
import array
from pydub import AudioSegment
from pydub.utils import get_array_type

sound = AudioSegment.from_file(file='8226164717312bc411f8635580562d67e191a754.mp3')
left = sound.split_to_mono()[0]

bit_depth = left.sample_width * 8
array_type = get_array_type(bit_depth)

numeric_array = array.array(array_type, left._data)

# %%
import matplotlib.pyplot as plt
plt.plot(numeric_array)

# %%
from scipy.fft import fft, fftfreq
freq=np.fft.rfft(numeric_array)
plt.plot(abs(freq))

# %%
from IPython.display import Audio
Audio(url=audios[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=c32a5873a74344fbb4a8e4a0731f6a13" type="None" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from __future__ import print_function    # (at top of module)
from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import sys


client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

if len(sys.argv) > 1:
    tid = sys.argv[1]
else:
    tid = 'spotify:track:4TTV7EcfroSLWzXRY6gLv6'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))
analysis = sp.audio_analysis('spotify:track:0ZK8TGOsngrstVPsnrHbK1')

# %%
print(analysis.keys())
#analysis['tatums']
# Out:
# dict_keys(['meta', 'track', 'bars', 'beats', 'sections', 'segments', 'tatums'])

# %%
artist_name = 'weezer'

results = sp.search(q=artist_name, limit=50)
tids = []
for i, t in enumerate(results['tracks']['items']):
    print(' ', i, t['name'])
    tids.append(t['uri'])
    
features = sp.audio_features(tids)
#print(features)


#for feature in features:
##    print(json.dumps(feature, indent=4))
#    print()
#    analysis = sp._get(feature['analysis_url'])
#    print(json.dumps(analysis, indent=4))
#    print()
features[0].keys()
# Out:
#   0 Say It Ain't So
#   1 Island In The Sun
#   2 Undone - The Sweater Song
#   3 Buddy Holly
#   4 Beverly Hills
#   5 Africa
#   6 Hash Pipe
#   7 All My Favorite Songs (feat. AJR)
#   8 My Name Is Jonas
#   9 Pork And Beans
#   10 Enter Sandman
#   11 Lost in the Woods - Weezer Version
#   12 Take on Me
#   13 Beverly Hills
#   14 Island In The Sun
#   15 Pink Triangle
#   16 (If You're Wondering If I Want You To) I Want You To
#   17 Feels Like Summer
#   18 All My Favorite Songs
#   19 El Scorcho
#   20 Only In Dreams
#   21 Perfect Situation
#   22 WEEZER
#   23 All My Favorite Songs
#   24 Weezer
#   25 Weezer
#   26 The World Has Turned And Left Me Here
#   27 Weezer
#   28 The Good Life
#   29 In The Garage
#   30 Weezer
#   31 Sound the Alarm (feat. Rivers Cuomo of Weezer & Royal & the Serpent)
#   32 Weezer
#   33 Weezer Medley
#   34 Weezer
#   35 Surf Wax America
#   36 Weezer
#   37 Pacific Coast Highway In The Movies (feat. Rivers Cuomo of Weezer)
#   38 Troublemaker
# ...

# %%
pd.DataFrame.from_dict(features)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.634  0.5510    3    -7.136     1       0.0352      0.007370
# 1          0.654  0.8100    4    -6.260     0       0.0288      0.007190
# 2          0.457  0.6180    6    -6.682     1       0.0296      0.001140
# 3          0.556  0.9200    8    -4.606     1       0.0367      0.002710
# 4          0.693  0.8230    5    -3.761     1       0.0726      0.093200
# 5          0.534  0.7840    8    -3.590     1       0.0339      0.205000
# 6          0.578  0.8820    7    -6.354     1       0.0440      0.000121
# 7          0.605  0.7000    4    -6.470     1       0.0277      0.009980
# 8          0.295  0.9400   11    -5.247     1       0.0449      0.000210
# 9          0.599  0.6240    6    -6.622     1       0.0339      0.010900
# 10         0.531  0.8500    3    -5.162     1       0.0485      0.001060
# 11         0.403  0.5980    8    -5.735     1       0.0241      0.198000
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = 'playlist-read-private'
sp = sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

results = sp.current_user_playlists(limit=50)
for i, item in enumerate(results['items']):
    print("%d %s" % (i, item['name']))
# Out:
# DEBUG:spotipy.client:Sending GET to https://api.spotify.com/v1/me/playlists with Params: {'limit': 50, 'offset': 0} Headers: {'Authorization': 'Bearer BQCPuMCeJDml7_Bwt8j4u2JWRDGb3QKAzhjxeSxGKP2x3DT7J7Coj5501hHIiaJKsJrEJxpqx4E9--AN7RQ', 'Content-Type': 'application/json'} and Body: None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.spotify.com:443
# DEBUG:urllib3.connectionpool:https://api.spotify.com:443 "GET /v1/me/playlists?limit=50&offset=0 HTTP/1.1" 401 None
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/me/playlists with Params: {'limit': 50, 'offset': 0} returned 401 due to Unauthorized.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
# ...

# %%
list(range(10,1,-1))
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %%
list(reversed(range(11,1)))
# Out:
# []

# %%
def test(x):
    x+2
    
    
test(2)==True
# Out:
# False

# %%
temp=[1,2,3]

print(temp.remove(2))
# Out:
# None

# %%
test = {
    'one':1,
    'two':2}

test.keys()
# Out:
# dict_keys(['one', 'two'])
